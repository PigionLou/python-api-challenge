# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

from api_keys import weather_api_key
from citipy import citipy
output_data_file = "output_data/cities.csv"
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
lat_lngs = []
cities = []

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 604

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
list_of_cities = []
clouds = []
countries = []
date = []
humidity = []
lats = []
langs = []
max_temp = []
wspeed = []
counter = 0
counter1 = 1

print("Beginning Data Retrieval ")
print("-------------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="

for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        list_of_cities.append(response["name"])
        clouds.append(response["clouds"]["all"])
        countries.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lats.append(response["coord"]["lat"])
        langs.append(response["coord"]["lon"])
        max_temp.append(response['main']['temp_max'])
        wspeed.append(response["wind"]["speed"])
        if counter > 49:
            counter = 0
            counter1 = counter1 + 1
        
        else:
            counter = counter + 1
        
        print(f"Processing Record {counter} of Set {counter1} : {city}")
        
    except(KeyError, IndexError):
        print("City not found. Moving to next.")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 : yulara
# Processing Record 2 of Set 1 : arrifes
# Processing Record 3 of Set 1 : hobart
# Processing Record 4 of Set 1 : westport
# Processing Record 5 of Set 1 : esperance
# Processing Record 6 of Set 1 : harper
# Processing Record 7 of Set 1 : whitehorse
# Processing Record 8 of Set 1 : port elizabeth
# Processing Record 9 of Set 1 : georgetown
# Processing Record 10 of Set 1 : cherskiy
# Processing Record 11 of Set 1 : ust-tsilma
# Processing Record 12 of Set 1 : vaini
# Processing Record 13 of Set 1 : san jeronimo
# Processing Record 14 of Set 1 : tasiilaq
# Processing Record 15 of Set 1 : busselton
# Processing Record 16 of Set 1 : lompoc
# Processing Record 17 of Set 1 : ribeira grande
# City not found. Moving to next.
# Processing Record 18 of Set 1 : lorengau
# Processing Record 19 of Set 1 : mataura
# Processing Record 20 of Set 1 : samarai
# Processing Record 21 of Set 1 : aitape
# Processing Record 22 of Set 1 : antalaha
# Processing Record 23 of Set 1 : imeni babushkina
# City not found. Moving to next.
# Processing Record 24 of Set 1 : port alfred
# Processing Record 25 of Set 1 : avarua
# Processing Record 26 of Set 1 : ushuaia
# Processing Record 27 of Set 1 : kapaa
# Processing Record 28 of Set 1 : quatre cocos
# City not found. Moving to next.
# Processing Record 29 of Set 1 : nikolskoye
# Processing Record 30 of Set 1 : geraldton
# Processing Record 31 of Set 1 : cape town
# Processing Record 32 of Set 1 : san carlos de bariloche
# Processing Record 33 of Set 1 : hithadhoo
# Processing Record 34 of Set 1 : hervey bay
# Processing Record 35 of Set 1 : atuona
# Processing Record 36 of Set 1 : barrow
# Processing Record 37 of Set 1 : asau
# Processing Record 38 of Set 1 : port-cartier
# Processing Record 39 of Set 1 : naryan-mar
# Processing Record 40 of Set 1 : mengcheng
# Processing Record 41 of Set 1 : dengzhou
# Processing Record 42 of Set 1 : lazarev
# Processing Record 43 of Set 1 : rikitea
# Processing Record 44 of Set 1 : torbay
# City not found. Moving to next.
# Processing Record 45 of Set 1 : pevek
# Processing Record 46 of Set 1 : mana
# Processing Record 47 of Set 1 : bluff
# Processing Record 48 of Set 1 : ca mau
# Processing Record 49 of Set 1 : puerto maldonado
# Processing Record 50 of Set 1 : dombarovskiy
# Processing Record 0 of Set 2 : thompson
# Processing Record 1 of Set 2 : taltal
# Processing Record 2 of Set 2 : hongjiang
# Processing Record 3 of Set 2 : goedereede
# Processing Record 4 of Set 2 : gizo
# Processing Record 5 of Set 2 : ngora
# Processing Record 6 of Set 2 : chokurdakh
# Processing Record 7 of Set 2 : qaanaaq
# Processing Record 8 of Set 2 : castro
# Processing Record 9 of Set 2 : faanui
# Processing Record 10 of Set 2 : bilma
# Processing Record 11 of Set 2 : taoudenni
# Processing Record 12 of Set 2 : cap malheureux
# Processing Record 13 of Set 2 : knysna
# City not found. Moving to next.
# Processing Record 14 of Set 2 : okha
# City not found. Moving to next.
# Processing Record 15 of Set 2 : yebaishou
# Processing Record 16 of Set 2 : bredasdorp
# City not found. Moving to next.
# Processing Record 17 of Set 2 : dingle
# Processing Record 18 of Set 2 : kichera
# Processing Record 19 of Set 2 : broome
# Processing Record 20 of Set 2 : hasaki
# Processing Record 21 of Set 2 : castelnau-le-lez
# Processing Record 22 of Set 2 : puerto ayora
# Processing Record 23 of Set 2 : provideniya
# Processing Record 24 of Set 2 : bambous virieux
# Processing Record 25 of Set 2 : vila velha
# Processing Record 26 of Set 2 : albany
# Processing Record 27 of Set 2 : liverpool
# Processing Record 28 of Set 2 : dikson
# Processing Record 29 of Set 2 : yar-sale
# Processing Record 30 of Set 2 : altay
# Processing Record 31 of Set 2 : klaksvik
# Processing Record 32 of Set 2 : skiathos
# City not found. Moving to next.
# Processing Record 33 of Set 2 : souillac
# Processing Record 34 of Set 2 : padang
# City not found. Moving to next.
# Processing Record 35 of Set 2 : nueve de julio
# Processing Record 36 of Set 2 : san patricio
# Processing Record 37 of Set 2 : saint-philippe
# City not found. Moving to next.
# Processing Record 38 of Set 2 : punta arenas
# Processing Record 39 of Set 2 : beira
# Processing Record 40 of Set 2 : hermanus
# Processing Record 41 of Set 2 : arraial do cabo
# Processing Record 42 of Set 2 : lebu
# Processing Record 43 of Set 2 : rapid valley
# City not found. Moving to next.
# Processing Record 44 of Set 2 : mount gambier
# Processing Record 45 of Set 2 : black river
# Processing Record 46 of Set 2 : benguela
# Processing Record 47 of Set 2 : hay river
# Processing Record 48 of Set 2 : kodiak
# Processing Record 49 of Set 2 : chissamba
# Processing Record 50 of Set 2 : ilulissat
# Processing Record 0 of Set 3 : saskylakh
# Processing Record 1 of Set 3 : vao
# Processing Record 2 of Set 3 : saint george
# Processing Record 3 of Set 3 : pontes e lacerda
# Processing Record 4 of Set 3 : tuktoyaktuk
# Processing Record 5 of Set 3 : caravelas
# Processing Record 6 of Set 3 : penzance
# Processing Record 7 of Set 3 : jamestown
# Processing Record 8 of Set 3 : kavieng
# Processing Record 9 of Set 3 : biltine
# Processing Record 10 of Set 3 : bengkulu
# Processing Record 11 of Set 3 : kungalv
# Processing Record 12 of Set 3 : longyearbyen
# Processing Record 13 of Set 3 : severnoye
# Processing Record 14 of Set 3 : alzamay
# Processing Record 15 of Set 3 : cidreira
# Processing Record 16 of Set 3 : mezen
# Processing Record 17 of Set 3 : rockport
# Processing Record 18 of Set 3 : fortuna
# Processing Record 19 of Set 3 : male
# Processing Record 20 of Set 3 : ancud
# Processing Record 21 of Set 3 : grand gaube
# Processing Record 22 of Set 3 : tiksi
# Processing Record 23 of Set 3 : rundu
# Processing Record 24 of Set 3 : xam nua
# Processing Record 25 of Set 3 : kruisfontein
# Processing Record 26 of Set 3 : san cristobal
# Processing Record 27 of Set 3 : lakes entrance
# City not found. Moving to next.
# Processing Record 28 of Set 3 : shirokiy
# Processing Record 29 of Set 3 : te anau
# Processing Record 30 of Set 3 : dubbo
# Processing Record 31 of Set 3 : comodoro rivadavia
# Processing Record 32 of Set 3 : dakar
# Processing Record 33 of Set 3 : victoria
# Processing Record 34 of Set 3 : imbituba
# Processing Record 35 of Set 3 : xai-xai
# Processing Record 36 of Set 3 : lasa
# Processing Record 37 of Set 3 : carnarvon
# Processing Record 38 of Set 3 : tura
# Processing Record 39 of Set 3 : varkkallai
# Processing Record 40 of Set 3 : filadelfia
# City not found. Moving to next.
# Processing Record 41 of Set 3 : itapipoca
# Processing Record 42 of Set 3 : bonthe
# Processing Record 43 of Set 3 : alice springs
# Processing Record 44 of Set 3 : belokurikha
# Processing Record 45 of Set 3 : paoua
# Processing Record 46 of Set 3 : kawalu
# Processing Record 47 of Set 3 : concepcion del oro
# Processing Record 48 of Set 3 : baykit
# Processing Record 49 of Set 3 : pozhva
# Processing Record 50 of Set 3 : houma
# Processing Record 0 of Set 4 : luanda
# Processing Record 1 of Set 4 : arrecife
# City not found. Moving to next.
# Processing Record 2 of Set 4 : butaritari
# Processing Record 3 of Set 4 : njeru
# Processing Record 4 of Set 4 : khandyga
# Processing Record 5 of Set 4 : severo-kurilsk
# Processing Record 6 of Set 4 : yellowknife
# Processing Record 7 of Set 4 : griffith
# Processing Record 8 of Set 4 : jalu
# Processing Record 9 of Set 4 : farafangana
# Processing Record 10 of Set 4 : ketchikan
# Processing Record 11 of Set 4 : parana
# Processing Record 12 of Set 4 : kaitangata
# Processing Record 13 of Set 4 : ust-charyshskaya pristan
# Processing Record 14 of Set 4 : santiago
# Processing Record 15 of Set 4 : saint-pierre
# Processing Record 16 of Set 4 : kumluca
# Processing Record 17 of Set 4 : alta floresta
# Processing Record 18 of Set 4 : tomatlan
# Processing Record 19 of Set 4 : coihaique
# Processing Record 20 of Set 4 : chuy
# Processing Record 21 of Set 4 : bethel
# Processing Record 22 of Set 4 : carutapera
# Processing Record 23 of Set 4 : ulladulla
# Processing Record 24 of Set 4 : gazanjyk
# Processing Record 25 of Set 4 : tabas
# Processing Record 26 of Set 4 : elizabeth city
# Processing Record 27 of Set 4 : medicine hat
# Processing Record 28 of Set 4 : xining
# Processing Record 29 of Set 4 : tashla
# Processing Record 30 of Set 4 : demba
# City not found. Moving to next.
# Processing Record 31 of Set 4 : ostrovnoy
# Processing Record 32 of Set 4 : huarmey
# Processing Record 33 of Set 4 : geesthacht
# Processing Record 34 of Set 4 : ahipara
# Processing Record 35 of Set 4 : ilebo
# Processing Record 36 of Set 4 : pochutla
# Processing Record 37 of Set 4 : ust-kuyga
# Processing Record 38 of Set 4 : airai
# Processing Record 39 of Set 4 : gbadolite
# Processing Record 40 of Set 4 : monrovia
# City not found. Moving to next.
# Processing Record 41 of Set 4 : saint-georges
# Processing Record 42 of Set 4 : rio grande
# Processing Record 43 of Set 4 : villa carlos paz
# Processing Record 44 of Set 4 : porto novo
# Processing Record 45 of Set 4 : betong
# Processing Record 46 of Set 4 : east london
# Processing Record 47 of Set 4 : pucallpa
# City not found. Moving to next.
# Processing Record 48 of Set 4 : mandal
# Processing Record 49 of Set 4 : mbuji-mayi
# Processing Record 50 of Set 4 : xichang
# Processing Record 0 of Set 5 : hazorasp
# Processing Record 1 of Set 5 : karacakoy
# Processing Record 2 of Set 5 : ayagoz
# Processing Record 3 of Set 5 : turka
# Processing Record 4 of Set 5 : mehamn
# Processing Record 5 of Set 5 : gao
# Processing Record 6 of Set 5 : sur
# Processing Record 7 of Set 5 : morant bay
# Processing Record 8 of Set 5 : kangalassy
# Processing Record 9 of Set 5 : roald
# Processing Record 10 of Set 5 : yakovlevo
# Processing Record 11 of Set 5 : hilo
# Processing Record 12 of Set 5 : plettenberg bay
# Processing Record 13 of Set 5 : mier
# Processing Record 14 of Set 5 : johannesburg
# Processing Record 15 of Set 5 : ibiruba
# Processing Record 16 of Set 5 : koutsouras
# Processing Record 17 of Set 5 : coahuayana
# City not found. Moving to next.
# Processing Record 18 of Set 5 : calama
# Processing Record 19 of Set 5 : karasjok
# Processing Record 20 of Set 5 : port hardy
# Processing Record 21 of Set 5 : new norfolk
# Processing Record 22 of Set 5 : hambantota
# Processing Record 23 of Set 5 : bubaque
# Processing Record 24 of Set 5 : cabo san lucas
# Processing Record 25 of Set 5 : moree
# City not found. Moving to next.
# Processing Record 26 of Set 5 : raudeberg
# Processing Record 27 of Set 5 : mahebourg
# Processing Record 28 of Set 5 : mizdah
# Processing Record 29 of Set 5 : aklavik
# Processing Record 30 of Set 5 : primo tapia
# Processing Record 31 of Set 5 : yorkton
# Processing Record 32 of Set 5 : constitucion
# City not found. Moving to next.
# Processing Record 33 of Set 5 : libreville
# Processing Record 34 of Set 5 : honiara
# Processing Record 35 of Set 5 : abu zabad
# City not found. Moving to next.
# City not found. Moving to next.
# City not found. Moving to next.
# Processing Record 36 of Set 5 : puerto escondido
# Processing Record 37 of Set 5 : lucea
# Processing Record 38 of Set 5 : rocha
# Processing Record 39 of Set 5 : palmer
# Processing Record 40 of Set 5 : talara
# Processing Record 41 of Set 5 : heidenreichstein
# Processing Record 42 of Set 5 : yuzhno-sukhokumsk
# Processing Record 43 of Set 5 : patiya
# Processing Record 44 of Set 5 : tessalit
# Processing Record 45 of Set 5 : sorland
# Processing Record 46 of Set 5 : saint anthony
# City not found. Moving to next.
# Processing Record 47 of Set 5 : sao joao dos patos
# Processing Record 48 of Set 5 : portland
# Processing Record 49 of Set 5 : lavrentiya
# City not found. Moving to next.
# Processing Record 50 of Set 5 : lagos
# Processing Record 0 of Set 6 : saeby
# Processing Record 1 of Set 6 : nome
# Processing Record 2 of Set 6 : rockingham
# Processing Record 3 of Set 6 : nagyrabe
# Processing Record 4 of Set 6 : hami
# Processing Record 5 of Set 6 : hue
# Processing Record 6 of Set 6 : severo-yeniseyskiy
# Processing Record 7 of Set 6 : non sung
# Processing Record 8 of Set 6 : lebedyn
# Processing Record 9 of Set 6 : sao filipe
# Processing Record 10 of Set 6 : kirensk
# Processing Record 11 of Set 6 : rawson
# Processing Record 12 of Set 6 : cabrera
# Processing Record 13 of Set 6 : san francisco
# City not found. Moving to next.
# Processing Record 14 of Set 6 : bilibino
# Processing Record 15 of Set 6 : broken hill
# Processing Record 16 of Set 6 : mount isa
# Processing Record 17 of Set 6 : sawakin
# Processing Record 18 of Set 6 : sambava
# Processing Record 19 of Set 6 : lichuan
# Processing Record 20 of Set 6 : shubarshi
# Processing Record 21 of Set 6 : petropavlovsk-kamchatskiy
# City not found. Moving to next.
# Processing Record 22 of Set 6 : aliganj
# City not found. Moving to next.
# Processing Record 23 of Set 6 : codrington
# Processing Record 24 of Set 6 : faya
# Processing Record 25 of Set 6 : martapura
# Processing Record 26 of Set 6 : baberu
# Processing Record 27 of Set 6 : port lincoln
# Processing Record 28 of Set 6 : almaznyy
# Processing Record 29 of Set 6 : kolyvan
# Processing Record 30 of Set 6 : khatanga
# Processing Record 31 of Set 6 : kandalaksha
# Processing Record 32 of Set 6 : norman wells
# Processing Record 33 of Set 6 : amloh
# Processing Record 34 of Set 6 : zhigansk
# Processing Record 35 of Set 6 : bebedouro
# Processing Record 36 of Set 6 : araouane
# Processing Record 37 of Set 6 : gujrat
# Processing Record 38 of Set 6 : kahului
# City not found. Moving to next.
# Processing Record 39 of Set 6 : betioky
# Processing Record 40 of Set 6 : peabiru
# Processing Record 41 of Set 6 : castlebar
# Processing Record 42 of Set 6 : rio gallegos
# Processing Record 43 of Set 6 : mareeba
# Processing Record 44 of Set 6 : bandarbeyla
# Processing Record 45 of Set 6 : baruun-urt
# Processing Record 46 of Set 6 : roseburg
# City not found. Moving to next.
# Processing Record 47 of Set 6 : omsukchan
# Processing Record 48 of Set 6 : krasnoarmeysk
# Processing Record 49 of Set 6 : hualmay
# Processing Record 50 of Set 6 : honningsvag
# Processing Record 0 of Set 7 : southbridge
# Processing Record 1 of Set 7 : cayenne
# Processing Record 2 of Set 7 : pundaguitan
# Processing Record 3 of Set 7 : zambezi
# Processing Record 4 of Set 7 : tynda
# Processing Record 5 of Set 7 : coffs harbour
# Processing Record 6 of Set 7 : araceli
# Processing Record 7 of Set 7 : bjelovar
# Processing Record 8 of Set 7 : anshun
# Processing Record 9 of Set 7 : isangel
# Processing Record 10 of Set 7 : salalah
# Processing Record 11 of Set 7 : conakry
# Processing Record 12 of Set 7 : nchelenge
# Processing Record 13 of Set 7 : leningradskiy
# City not found. Moving to next.
# Processing Record 14 of Set 7 : henties bay
# City not found. Moving to next.
# Processing Record 15 of Set 7 : darovskoy
# Processing Record 16 of Set 7 : walvis bay
# Processing Record 17 of Set 7 : caconda
# Processing Record 18 of Set 7 : clyde river
# Processing Record 19 of Set 7 : axim
# Processing Record 20 of Set 7 : lufilufi
# Processing Record 21 of Set 7 : shelburne
# Processing Record 22 of Set 7 : nemuro
# Processing Record 23 of Set 7 : cap-aux-meules
# Processing Record 24 of Set 7 : marga
# Processing Record 25 of Set 7 : anadyr
# Processing Record 26 of Set 7 : kununurra
# Processing Record 27 of Set 7 : rincon
# Processing Record 28 of Set 7 : inuvik
# Processing Record 29 of Set 7 : sisimiut
# Processing Record 30 of Set 7 : gorontalo
# Processing Record 31 of Set 7 : general pico
# Processing Record 32 of Set 7 : neiafu
# Processing Record 33 of Set 7 : zyryanka
# Processing Record 34 of Set 7 : vagay
# Processing Record 35 of Set 7 : luderitz
# City not found. Moving to next.
# Processing Record 36 of Set 7 : mathbaria
# Processing Record 37 of Set 7 : bara
# Processing Record 38 of Set 7 : nioro
# Processing Record 39 of Set 7 : coquimbo
# Processing Record 40 of Set 7 : grindavik
# City not found. Moving to next.
# Processing Record 41 of Set 7 : paidha
# Processing Record 42 of Set 7 : shache
# Processing Record 43 of Set 7 : idritsa
# Processing Record 44 of Set 7 : quchan
# Processing Record 45 of Set 7 : leiyang
# Processing Record 46 of Set 7 : vila franca do campo
# Processing Record 47 of Set 7 : kokkola
# Processing Record 48 of Set 7 : upernavik
# Processing Record 49 of Set 7 : ginda
# Processing Record 50 of Set 7 : ballina
# Processing Record 0 of Set 8 : tabou
# Processing Record 1 of Set 8 : kichmengskiy gorodok
# Processing Record 2 of Set 8 : beringovskiy
# Processing Record 3 of Set 8 : marquette
# Processing Record 4 of Set 8 : hofn
# Processing Record 5 of Set 8 : musoma
# Processing Record 6 of Set 8 : vanimo
# Processing Record 7 of Set 8 : smidovich
# Processing Record 8 of Set 8 : ponta do sol
# Processing Record 9 of Set 8 : cabras
# City not found. Moving to next.
# Processing Record 10 of Set 8 : talaya
# Processing Record 11 of Set 8 : grafton
# Processing Record 12 of Set 8 : gasa
# Processing Record 13 of Set 8 : egvekinot
# Processing Record 14 of Set 8 : olmos
# Processing Record 15 of Set 8 : sidi ali
# Processing Record 16 of Set 8 : horsham
# Processing Record 17 of Set 8 : vardo
# Processing Record 18 of Set 8 : sao joao da barra
# Processing Record 19 of Set 8 : sampit
# Processing Record 20 of Set 8 : merauke
# Processing Record 21 of Set 8 : batagay-alyta
# Processing Record 22 of Set 8 : puerto colombia
# Processing Record 23 of Set 8 : pondicherry
# Processing Record 24 of Set 8 : saint-paul
# Processing Record 25 of Set 8 : pacific grove
# Processing Record 26 of Set 8 : guerrero negro
# Processing Record 27 of Set 8 : mlonggo
# Processing Record 28 of Set 8 : deputatskiy
# Processing Record 29 of Set 8 : agirish
# Processing Record 30 of Set 8 : sola
# Processing Record 31 of Set 8 : karratha
# Processing Record 32 of Set 8 : yenagoa
# Processing Record 33 of Set 8 : olafsvik
# Processing Record 34 of Set 8 : coruripe
# Processing Record 35 of Set 8 : miracema
# Processing Record 36 of Set 8 : jiaojiang
# Processing Record 37 of Set 8 : opuwo
# City not found. Moving to next.
# Processing Record 38 of Set 8 : vrangel
# City not found. Moving to next.
# Processing Record 39 of Set 8 : kavaratti
# Processing Record 40 of Set 8 : tahta
# Processing Record 41 of Set 8 : killarney
# Processing Record 42 of Set 8 : kalangala
# Processing Record 43 of Set 8 : inta
# Processing Record 44 of Set 8 : bathsheba
# Processing Record 45 of Set 8 : salekhard
# Processing Record 46 of Set 8 : sao luis do quitunde
# Processing Record 47 of Set 8 : mpanda
# Processing Record 48 of Set 8 : beloha
# Processing Record 49 of Set 8 : nishihara
# Processing Record 50 of Set 8 : esil
# Processing Record 0 of Set 9 : valparaiso
# Processing Record 1 of Set 9 : dzerzhinsk
# Processing Record 2 of Set 9 : dabat
# Processing Record 3 of Set 9 : bunol
# Processing Record 4 of Set 9 : meulaboh
# City not found. Moving to next.
# Processing Record 5 of Set 9 : saldanha
# City not found. Moving to next.
# Processing Record 6 of Set 9 : asfi
# Processing Record 7 of Set 9 : redlands
# Processing Record 8 of Set 9 : burnie
# Processing Record 9 of Set 9 : kjustendil
# Processing Record 10 of Set 9 : inyonga
# Processing Record 11 of Set 9 : porto nacional
# Processing Record 12 of Set 9 : wanning
# Processing Record 13 of Set 9 : takoradi
# Processing Record 14 of Set 9 : prince rupert
# Processing Record 15 of Set 9 : emerald
# Processing Record 16 of Set 9 : berlevag
# Processing Record 17 of Set 9 : senneterre
# Processing Record 18 of Set 9 : jasper
# Processing Record 19 of Set 9 : ambilobe
# Processing Record 20 of Set 9 : wencheng
# Processing Record 21 of Set 9 : pilar
# Processing Record 22 of Set 9 : hidrolandia
# Processing Record 23 of Set 9 : aswan
# Processing Record 24 of Set 9 : fort nelson
# Processing Record 25 of Set 9 : katsuura
# City not found. Moving to next.
# Processing Record 26 of Set 9 : danielskuil
# Processing Record 27 of Set 9 : brae
# Processing Record 28 of Set 9 : zvishavane
# Processing Record 29 of Set 9 : kemijarvi
# Processing Record 30 of Set 9 : patan
# Processing Record 31 of Set 9 : murgab
# Processing Record 32 of Set 9 : kloulklubed
# Processing Record 33 of Set 9 : batemans bay
# City not found. Moving to next.
# Processing Record 34 of Set 9 : contai
# Processing Record 35 of Set 9 : bereda
# Processing Record 36 of Set 9 : camopi
# Processing Record 37 of Set 9 : dwarka
# Processing Record 38 of Set 9 : poum
# Processing Record 39 of Set 9 : praia da vitoria
# City not found. Moving to next.
# Processing Record 40 of Set 9 : narsaq
# Processing Record 41 of Set 9 : ngunguru
# Processing Record 42 of Set 9 : sibay
# Processing Record 43 of Set 9 : verkhniye sergi
# Processing Record 44 of Set 9 : hudson bay
# Processing Record 45 of Set 9 : santa maria
# Processing Record 46 of Set 9 : fare
# Processing Record 47 of Set 9 : yinchuan
# Processing Record 48 of Set 9 : wanaka
# Processing Record 49 of Set 9 : mayor pablo lagerenza
# Processing Record 50 of Set 9 : marataizes
# Processing Record 0 of Set 10 : marawi
# Processing Record 1 of Set 10 : itoman
# Processing Record 2 of Set 10 : mamakan
# Processing Record 3 of Set 10 : lazaro cardenas
# Processing Record 4 of Set 10 : iqaluit
# Processing Record 5 of Set 10 : severomuysk
# Processing Record 6 of Set 10 : nador
# Processing Record 7 of Set 10 : san gabriel
# Processing Record 8 of Set 10 : mumford
# Processing Record 9 of Set 10 : eenhana
# Processing Record 10 of Set 10 : beidao
# Processing Record 11 of Set 10 : diamantino
# Processing Record 12 of Set 10 : atasu
# Processing Record 13 of Set 10 : atar
# Processing Record 14 of Set 10 : ugoofaaru
# Processing Record 15 of Set 10 : hokitika
# Processing Record 16 of Set 10 : xuddur
# Processing Record 17 of Set 10 : yuci
# Processing Record 18 of Set 10 : charters towers
# Processing Record 19 of Set 10 : winslow
# Processing Record 20 of Set 10 : kaseda
# Processing Record 21 of Set 10 : inhambane
# Processing Record 22 of Set 10 : waimana
# Processing Record 23 of Set 10 : lensk
# Processing Record 24 of Set 10 : dunedin
# Processing Record 25 of Set 10 : derzhavinsk
# Processing Record 26 of Set 10 : assiniboia
# Processing Record 27 of Set 10 : bosaso
# Processing Record 28 of Set 10 : shingu
# City not found. Moving to next.
# Processing Record 29 of Set 10 : novorzhev
# Processing Record 30 of Set 10 : aras
# Processing Record 31 of Set 10 : maceio
# Processing Record 32 of Set 10 : pachino
# Processing Record 33 of Set 10 : chimbote
# Processing Record 34 of Set 10 : halifax
# Processing Record 35 of Set 10 : wuwei
# Processing Record 36 of Set 10 : belmonte
# Processing Record 37 of Set 10 : panguna
# Processing Record 38 of Set 10 : ulaangom
# Processing Record 39 of Set 10 : husavik
# Processing Record 40 of Set 10 : kuytun
# Processing Record 41 of Set 10 : san juan
# Processing Record 42 of Set 10 : salobrena
# Processing Record 43 of Set 10 : jumla
# Processing Record 44 of Set 10 : kenitra
# Processing Record 45 of Set 10 : hamilton
# Processing Record 46 of Set 10 : sapa
# Processing Record 47 of Set 10 : leshukonskoye
# Processing Record 48 of Set 10 : kargasok
# Processing Record 49 of Set 10 : obo
# Processing Record 50 of Set 10 : price
# Processing Record 0 of Set 11 : ayan
# Processing Record 1 of Set 11 : arica
# Processing Record 2 of Set 11 : zhangye
# Processing Record 3 of Set 11 : ishimbay
# Processing Record 4 of Set 11 : vaitape
# Processing Record 5 of Set 11 : inirida
# Processing Record 6 of Set 11 : suhbaatar
# Processing Record 7 of Set 11 : nanpiao
# Processing Record 8 of Set 11 : korla
# Processing Record 9 of Set 11 : beyla
# Processing Record 10 of Set 11 : nakhon sawan
# Processing Record 11 of Set 11 : dhidhdhoo
# City not found. Moving to next.
# Processing Record 12 of Set 11 : leh
# Processing Record 13 of Set 11 : sandovo
# Processing Record 14 of Set 11 : kosonsoy
# Processing Record 15 of Set 11 : atalanti
# Processing Record 16 of Set 11 : angra dos reis
# Processing Record 17 of Set 11 : dalnerechensk
# Processing Record 18 of Set 11 : tual
# Processing Record 19 of Set 11 : antofagasta
# City not found. Moving to next.
# Processing Record 20 of Set 11 : komsomolskiy
# Processing Record 21 of Set 11 : bejar
# Processing Record 22 of Set 11 : kirakira
# Processing Record 23 of Set 11 : fosforitnyy
# Processing Record 24 of Set 11 : roura
# Processing Record 25 of Set 11 : itarema
# Processing Record 26 of Set 11 : ornskoldsvik
# Processing Record 27 of Set 11 : cotonou
# Processing Record 28 of Set 11 : erzin
# Processing Record 29 of Set 11 : katobu
# Processing Record 30 of Set 11 : valadares
# Processing Record 31 of Set 11 : acapulco
# Processing Record 32 of Set 11 : college
# Processing Record 33 of Set 11 : sokolo
# Processing Record 34 of Set 11 : guadalupe victoria
# Processing Record 35 of Set 11 : canavieiras
# Processing Record 36 of Set 11 : orlik
# Processing Record 37 of Set 11 : iquique
# Processing Record 38 of Set 11 : buraydah
# City not found. Moving to next.
# Processing Record 39 of Set 11 : simbahan
# Processing Record 40 of Set 11 : nizhniy odes
# Processing Record 41 of Set 11 : maragogi
# Processing Record 42 of Set 11 : soyo
# Processing Record 43 of Set 11 : horodyshche
# Processing Record 44 of Set 11 : derby
# Processing Record 45 of Set 11 : haines junction
# Processing Record 46 of Set 11 : luganville
# Processing Record 47 of Set 11 : wattegama
# Processing Record 48 of Set 11 : camacha

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = pd.DataFrame({ 
                "City" : list_of_cities,
                "Cloudiness" : clouds,
                "Country" : countries,
                "Date" : date,
                "Humidity" : humidity,
                "Lat" : lats,
                "Lng" : langs,
                "Max Temp" : max_temp,
                "Wind Speed" : wspeed
    })

# %%
weather_dict.count()
# Out:
# City          558
# Cloudiness    558
# Country       558
# Date          558
# Humidity      558
# Lat           558
# Lng           558
# Max Temp      558
# Wind Speed    558
# dtype: int64

# %%
weather_dict
# Out:
#                 City  Cloudiness Country        Date  Humidity      Lat  \
# 0             Yulara          75      AU  1635037176        22 -25.2406
# 1            Arrifes          20      PT  1635037177        72  37.7667
# 2             Hobart          75      AU  1635036859        71 -42.8794
# 3           Westport          89      US  1635037049        79  41.1415
# 4          Esperance           2      AU  1635037177        44 -33.8667
# ..               ...         ...     ...         ...       ...      ...
# 553            Derby          75      GB  1635037352        76  52.9228
# 554  Haines Junction          95      CA  1635037271        85  60.7522
# 555       Luganville          38      VU  1635037353        73 -15.5333
# 556        Wattegama          96      LK  1635037353        87   6.7989
# 557          Camacha          40      PT  1635037353        56  33.0833
#
#           Lng  Max Temp  Wind Speed
# 0    130.9889     75.04       20.71
# 1    -25.7000     64.65        8.05
# 2    147.3294     54.10        5.01
# 3    -73.3579     57.79        3.00
# 4    121.9000     62.44       16.44
# ..        ...       ...         ...
# 553   -1.4766     53.51       12.66
# 554 -137.5108     36.32        4.29
# 555  167.1667     83.52        8.43
# 556   81.4808     74.32        1.36
# 557  -16.3333     66.96        9.22
#
# [558 rows x 9 columns]

# %%
weather_dict.to_csv("../output_data/cities.csv", index = False)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_dict["Lat"], weather_dict["Max Temp"], facecolor = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Laitude")
plt.ylabel("Max Temperature (F)")
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)
plt.savefig("../Images/City Latitude vs Max Temperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_dict["Lat"], weather_dict["Humidity"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Humidity")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Humidity (%)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_dict["Lat"], weather_dict["Cloudiness"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Cloudiness")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Cloudiness (%)")

# Set y axis limit
plt.ylim(-5,105)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_dict["Lat"], weather_dict["Wind Speed"], facecolor = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Wind Speed (mph)")
plt.xlabel("Laitude")
plt.ylabel("Wind Speed (%)")
plt.ylim(-2,50)
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)
plt.savefig("../Images/City Latitude vs Wind Speed (mph).png")

# %% [markdown]
# ## Linear Regression

# %%
northern_hemisphere = weather_dict.loc[weather_dict["Lat"] >= 0]
southern_hemisphere = weather_dict.loc[weather_dict["Lat"] < 0]
def linear_agression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])
annotate(equation, 0, 0)
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.savefig("../Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-7666353b3549> in <module>
# ----> 1 equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])
#       2 annotate(equation, 0, 0)
#       3 plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
#       4 plt.xlabel("Latitude")
#       5 plt.ylabel("Max Temp (F)")
#
# <ipython-input-12-60c46f9cea8d> in linear_agression(x, y)
#       2 southern_hemisphere = weather_dict.loc[weather_dict["Lat"] < 0]
#       3 def linear_agression(x,y):
# ----> 4     print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
#       5     (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
#       6     regress_values = x * slope + intercept
#
# NameError: name 'st' is not defined

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
equation = linear_agression(southern_hemisphere["Lat"],southern_hemisphere["Max Temp"])
annotate(equation, -30, 50)
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.savefig("../Images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])
annotate(equation, 40, 15)
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("../Images/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])
annotate(equation, -40, 50)
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("../Images/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])
annotate(equation, 30, 40)
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("../Images/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])
annotate(equation, -30, 40)
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("../Images/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])
annotate(equation, 40, 20)
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("../Images/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])
annotate(equation, -30, 15)
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("../Images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
